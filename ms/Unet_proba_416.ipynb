# %%
class MyDataset(...):
  def init(self, path2data):
    paths2images = [os.path.join(path2data, image) for image in os.listdir(path2data)]
    texts = [text for text in ...]

  def getitem(self, i):
    image = np.array(Image.open(paths2images[i]))
    # preprocess your photo
    image_as_vector = get_vector_from_image(image)

    # Same with text
    text_as_vector = ...

    return image_as_vector, text_as_vector

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install torchmetrics
# !pip install segmentation_models_pytorch



import sys
import os, cv2
import numpy as np
import pandas as pd
import random, tqdm
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import albumentations as album
from torchmetrics import JaccardIndex
import segmentation_models_pytorch as smp
from segmentation_models_pytorch import utils
import gc


import PIL
from PIL import Image

import os, cv2
import numpy as np
import pandas as pd
import random, tqdm
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import albumentations as album

import PIL
from PIL import Image
import segmentation_models_pytorch as smp


# Perform one hot encoding on label
def one_hot_encode(label, label_values):
    """
    Convert a segmentation image label array to one-hot format
    by replacing each pixel value with a vector of length num_classes
    # Arguments
        label: The 2D array segmentation image label
        label_values

    # Returns
        A 2D array with the same width and hieght as the input, but
        with a depth size of num_classes
    """
    semantic_map = []
    for colour in label_values:
        equality = np.equal(label, colour)
        class_map = np.all(equality, axis = -1)
        semantic_map.append(class_map)
    semantic_map = np.stack(semantic_map, axis=-1)

    return semantic_map

# Perform reverse one-hot-encoding on labels / preds
def reverse_one_hot(image):
    """
    Transform a 2D array in one-hot format (depth is num_classes),
    to a 2D array with only 1 channel, where each pixel value is
    the classified class key.
    # Arguments
        image: The one-hot format image

    # Returns
        A 2D array with the same width and hieght as the input, but
        with a depth size of 1, where each pixel value is the classified
        class key.
    """
    x = np.argmax(image, axis = -1)
    return x

# Perform colour coding on the reverse-one-hot outputs
def colour_code_segmentation(image, label_values):
    """
    Given a 1-channel array of class keys, colour code the segmentation results.
    # Arguments
        image: single channel array where each value represents the class key.
        label_values

    # Returns
        Colour coded image for segmentation visualization
    """
    colour_codes = np.array(label_values)
    x = colour_codes[image.astype(int)]

    return x
class DefectsDataset(torch.utils.data.Dataset):

    """Read images, apply augmentation and preprocessing transformations.

    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_rgb_values (list): RGB values of select classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing
            (e.g. normalization, shape manipulation, etc.)

    """

    def __init__(
            self,
            images_dir: str,
            masks_dir: str,
            class_rgb_values=None,
            augmentation=None,
            preprocessing=None,
            mask_format = 'np',
            size=-1
    ):

        self.image_paths = [os.path.join(images_dir, image_id) for image_id in sorted(os.listdir(images_dir))]#[:size]
        self.mask_paths = [os.path.join(masks_dir, image_id) for image_id in sorted(os.listdir(masks_dir))]#[:size]

        self.class_rgb_values = class_rgb_values
        self.augmentation = augmentation
        self.preprocessing = preprocessing
        self.mask_format = mask_format

    def __getitem__(self, i):

        # read images and masks
        #image = cv2.cvtColor(cv2.imread(self.image_paths[i]), cv2.COLOR_BGR2RGB)
        #mask = cv2.cvtColor(cv2.imread(self.mask_paths[i]), cv2.COLOR_BGR2RGB)

        image = np.array(Image.open(self.image_paths[i]))
        if self.mask_format == 'np':
          mask = np.load(self.mask_paths[i])
        else:
          mask = np.array(Image.open(self.mask_paths[i]))


        # one-hot-encode the mask
        mask = one_hot_encode(mask, self.class_rgb_values).astype('float')

        # apply augmentations
        if self.augmentation:
            #print(self.image_paths[i])
            #print(i)
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        return image, mask

    def __len__(self):
        # return length of
        return len(self.image_paths)

def visualize(**images):
    """
    Plot images in one row
    """
    n_images = len(images)
    plt.figure(figsize=(20,8))
    for idx, (name, image) in enumerate(images.items()):
        plt.subplot(1, n_images, idx + 1)
        plt.xticks([]);
        plt.yticks([])
        # get title from the parameter names
        plt.title(name.replace('_',' ').title(), fontsize=20)
        plt.imshow(image)
    plt.show()

#def get_training_augmentation():
#    test_transform = [
#        album.PadIfNeeded(min_height=2368, min_width=2368, always_apply=True, border_mode=0),
#    ]
#    return album.Compose(test_transform)

# Here you can specify constant or probabilistic augmentation
def get_training_augmentation():
    train_transform = [
        album.RandomCrop(height=416, width=416, always_apply=True),
        album.OneOf(
            [
                album.HorizontalFlip(p=1),
                album.VerticalFlip(p=1),
                album.RandomRotate90(p=1),
            ],
            p=0.75,
        ),
    ]
    return album.Compose(train_transform)

# Here you can specify constant or probabilistic augmentation
def get_validation_augmentation():
    # Add sufficient padding to ensure image is divisible by 32
    test_transform = [
        album.PadIfNeeded(min_height=3040, min_width=4032, always_apply=True, border_mode=1),
    ]
    return album.Compose(test_transform)


def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')


def get_preprocessing(preprocessing_fn=None):
    """Construct preprocessing transform
    Args:
        preprocessing_fn (callable): data normalization function
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    """
    _transform = []
    if preprocessing_fn:
        _transform.append(album.Lambda(image=preprocessing_fn))
    _transform.append(album.Lambda(image=to_tensor, mask=to_tensor))

    return album.Compose(_transform)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class_names = ['background', 'defect']
class_rgb_values = [[0, 255, 0], [255, 0, 0]]

# %%
ENCODER = 'resnet50'
ENCODER_WEIGHTS = 'imagenet'
CLASSES = class_names
ACTIVATION = 'sigmoid' # could be None for logits or 'softmax2d' for multiclass segmentation

# create segmentation model with pretrained encoder
model = smp.Unet(
    encoder_name=ENCODER,
    encoder_weights=ENCODER_WEIGHTS,
    classes=len(CLASSES),
    activation=ACTIVATION,
)
#model = torch.load(f'/content/drive/MyDrive/Defects/Models/best_model_10_{0}_epoch.pth')

preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# %%
DATA_DIR = "/content/drive/MyDrive/Кирпичи дефекты/Data/no_aug"

# Directories of train, test etc.
x_train_dir = os.path.join(DATA_DIR, 'TRAIN/original')
y_train_dir = os.path.join(DATA_DIR, 'TRAIN/segment')

x_valid_dir = os.path.join(DATA_DIR, 'VAL/original')
y_valid_dir = os.path.join(DATA_DIR, 'VAL/segment')

x_test_dir = os.path.join(DATA_DIR, 'TEST/original')
y_test_dir = os.path.join(DATA_DIR, 'TEST/segment')

# Here you can specify constant or probabilistic augmentation
# def get_training_augmentation_():
#     test_transform = [
#        #album.PadIfNeeded(min_height=288, min_width=288, always_apply=True, border_mode=0),
#        album.PadIfNeeded(min_height=416, min_width=416, always_apply=True, border_mode=0),
#     ]
#     return album.Compose(test_transform)

def get_validation_augmentation_():
    # Add sufficient padding to ensure image is divisible by 32
    test_transform = [
        #album.PadIfNeeded(min_height=288, min_width=288, always_apply=True, border_mode=0),
        album.PadIfNeeded(min_height=416, min_width=416, always_apply=True, border_mode=0),
    ]
    return album.Compose(test_transform)

train_dataset = DefectsDataset(
    x_train_dir, y_train_dir,
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocessing_fn),
    class_rgb_values=class_rgb_values,
    mask_format='png'
)

valid_dataset = DefectsDataset(
    x_valid_dir, y_valid_dir,
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocessing_fn),
    class_rgb_values=class_rgb_values,
    mask_format='png'
)

# Get train and val data loaders
train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True, num_workers=1)
valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False, num_workers=1)

# %%
for i in range(len(train_dataset)):
  x, y = train_dataset[0]
  print(x.shape)
  print(y.shape)
  print('------------')
# Out:
# (3, 416, 416)
# (2, 416, 416)
# ------------
# (3, 416, 416)
# (2, 416, 416)
# ------------
# (3, 416, 416)
# (2, 416, 416)
# ------------
# (3, 416, 416)
# (2, 416, 416)
# ------------
# (3, 416, 416)
# (2, 416, 416)
# ------------
# (3, 416, 416)
# (2, 416, 416)
# ------------
# (3, 416, 416)
# (2, 416, 416)
# ------------
# (3, 416, 416)
# (2, 416, 416)
# ------------
# (3, 416, 416)
# (2, 416, 416)
# ------------

# %%
torch.Tensor(train_dataset[0][0]).shape#[None, :, :, :].shape
# Out:
# torch.Size([3, 416, 416])

# %%
model(torch.Tensor(train_dataset[-2][0])[None, :, :, :].cuda()).shape
# Out:
# torch.Size([1, 2, 416, 416])

# %%
x.shape
# Out:
# (3, 288, 288)

# %%
y.shape
# Out:
# (2, 288, 288)

# %%
train_dataset[-1][1].shape
# Out:
# (2, 416, 416)

# %%
len(valid_loader)
# Out:
# 2

# %%
from tqdm.auto import tqdm as tqdm
for batch in tqdm(train_loader):
  X, y = batch
  print(X.shape)
  print(y.shape)
  output = model(X.to('cuda'))
  print(output.shape)
  print('----------')
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# /content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/original/1.png
# 0
# /content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/original/16.png
# 2
# /content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/original/IMG_0370.png
# 4
# /content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/original/IMG_0370.png
# 4
# torch.Size([2, 3, 416, 416])
# torch.Size([2, 2, 416, 416])
# torch.Size([2, 2, 416, 416])
# ----------
# /content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/original/IMG_0373.png
# 5
# /content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/original/IMG_0377.png
# 7
# /content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/original/2.png
# 3
# /content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/original/2.png
# 3
# torch.Size([2, 3, 416, 416])
# torch.Size([2, 2, 416, 416])
# torch.Size([2, 2, 416, 416])
# ----------
# /content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/original/1.png
# 0
# /content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/original/IMG_0376.png
# 6
# torch.Size([2, 3, 416, 416])
# torch.Size([2, 2, 416, 416])
# torch.Size([2, 2, 416, 416])
# ----------
# /content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/original/15.png
# 1
# /content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/original/IMG_0373.png
# 5
# torch.Size([2, 3, 416, 416])
# torch.Size([2, 2, 416, 416])
# torch.Size([2, 2, 416, 416])
# ----------

# %%
        image = np.array(Image.open('/content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/original/IMG_0360.png'))
        mask = np.array(Image.open('/content/drive/MyDrive/Кирпичи дефекты/Data/no_aug/TRAIN/segment/IMG_0360.png'))

# %%
image.shape
# Out:
# (3024, 4032, 3)

# %%
mask.shape
# Out:
# (2268, 4032, 3)

# %%
from segmentation_models_pytorch import utils
TRAINING = True

# Set num of epochs
EPOCHS = 300

# Set device: `cuda` or `cpu`
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# define loss function
#loss = smp.utils.losses.DiceLoss()#DiceLoss_()#
loss = torch.nn.BCELoss()

# define metrics
metrics = [
    #IoU_(),
    smp.utils.metrics.IoU(threshold=0.5),
    smp.utils.metrics.Fscore(threshold=0.5),
    smp.utils.metrics.Accuracy(threshold=0.5),
    smp.utils.metrics.Recall(threshold=0.5),
    smp.utils.metrics.Precision(threshold=0.5),
    #Precision(),
    #Recall(),
    #F1(),
    #Accuracy()
    #smp.utils.metrics.IoU(threshold=0.5),
]

# define optimizer
optimizer = torch.optim.Adam([
    dict(params=model.parameters(), lr=0.0001),
])

# %%
train_epoch = smp.utils.train.TrainEpoch(
    model,
    loss=loss,
    metrics=metrics,
    optimizer=optimizer,
    device=DEVICE,
    verbose=True,
)

valid_epoch = smp.utils.train.ValidEpoch(
    model,
    loss=loss,
    metrics=metrics,
    device=DEVICE,
    verbose=True,
)

# %%
# !pip install wandb
import wandb
wandb.login(key='028f2bb73f8d6aa6ae54ccfb3d22b397309bbdd0')
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.15.12)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.40)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.34.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.10/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# wandb: Currently logged in as: s_artamonov. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# %%time
wandb.init(
      # Set the project where this run will be logged
      project="Brics_unet",
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{1}_300_epoch_bce",
      # Track hyperparameters and run metadata
      config={
      "learning_rate": 0.0001,
      "architecture": "Unet-_400",
      "dataset": "Own",
      "epochs": 300,
      "comment": 'proba_augm400'
      })
# Out:
# Finishing last run (ID:ynpv7o5z) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">experiment_1_300_epoch_bce</strong> at: <a href='https://wandb.ai/s_artamonov/Brics_unet/runs/ynpv7o5z' target="_blank">https://wandb.ai/s_artamonov/Brics_unet/runs/ynpv7o5z</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231105_153552-ynpv7o5z/logs</code>
# Successfully finished last run (ID:ynpv7o5z). Initializing new run:<br/>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231105_153714-bgxbefik</code>
# Syncing run <strong><a href='https://wandb.ai/s_artamonov/Brics_unet/runs/bgxbefik' target="_blank">experiment_1_300_epoch_bce</a></strong> to <a href='https://wandb.ai/s_artamonov/Brics_unet' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/s_artamonov/Brics_unet' target="_blank">https://wandb.ai/s_artamonov/Brics_unet</a>
#  View run at <a href='https://wandb.ai/s_artamonov/Brics_unet/runs/bgxbefik' target="_blank">https://wandb.ai/s_artamonov/Brics_unet/runs/bgxbefik</a>
# CPU times: user 131 ms, sys: 13.5 ms, total: 144 ms
# Wall time: 6.7 s
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/s_artamonov/Brics_unet/runs/bgxbefik?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
loss.__name__ = 'bce'

# %%
if TRAINING:

    best_iou_score = 0.0
    train_logs_list, valid_logs_list = [], []

    for i in range(0, 300):

        # Perform training & validation
        print('\nEpoch: {}'.format(i))
        train_logs = train_epoch.run(train_loader)
        valid_logs = valid_epoch.run(valid_loader)
        train_logs_list.append(train_logs)
        valid_logs_list.append(valid_logs)

        #val_loss = valid_logs['dice_loss']
        #train_loss = train_logs['dice_loss']
        val_loss = valid_logs['bce']
        train_loss = train_logs['bce']
        val_iou = valid_logs['iou_score']
        train_iou = train_logs['iou_score']


        wandb.log({"train/Loss": train_loss,
                   "val/Loss": val_loss,
                   "train/IoU": train_iou,
                   "val/IoU": val_iou,
                   "train/precision": train_logs['precision'],
                   "val/precision": valid_logs['precision'],
                   "train/recall": train_logs['recall'],
                   "val/recall": valid_logs['recall'],
                   "train/f1": train_logs['fscore'],
                   "val/f1": valid_logs['fscore'],
                   "train/acc": train_logs['accuracy'],
                   "val/acc": valid_logs['accuracy']})
        if i%5 == 0:
            torch.save(model.state_dict(), f'/content/drive/MyDrive/Кирпичи дефекты/Models/Unet/Experiment_1/model_{i+1}_epoch.pth')
        # # Save model if a better val IoU score is obtained
        if best_iou_score < valid_logs['iou_score']:
             best_iou_score = valid_logs['iou_score']
             torch.save(model, '/content/drive/MyDrive/Кирпичи дефекты/Models/Unet/Experiment_1/best_model.pth')
             print('Model saved!')
# Out:
# Epoch: 0
# train: 100%|██████████| 4/4 [00:13<00:00,  3.28s/it, bce - 0.9338, iou_score - 0.363, fscore - 0.5326, accuracy - 0.4149, recall - 0.6667, precision - 0.4434]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.41s/it, bce - 0.6982, iou_score - 0.4643, fscore - 0.6339, accuracy - 0.4812, recall - 0.8998, precision - 0.4894]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 4/4 [00:12<00:00,  3.01s/it, bce - 0.9201, iou_score - 0.3971, fscore - 0.5683, accuracy - 0.462, recall - 0.7083, precision - 0.4746]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.16s/it, bce - 0.781, iou_score - 0.3862, fscore - 0.5551, accuracy - 0.3945, recall - 0.762, precision - 0.4371]
#
# Epoch: 2
# train: 100%|██████████| 4/4 [00:12<00:00,  3.10s/it, bce - 0.8565, iou_score - 0.4425, fscore - 0.6134, accuracy - 0.5178, recall - 0.7649, precision - 0.512]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.37s/it, bce - 0.8254, iou_score - 0.3796, fscore - 0.5481, accuracy - 0.395, recall - 0.7408, precision - 0.4356]
#
# Epoch: 3
# train: 100%|██████████| 4/4 [00:12<00:00,  3.23s/it, bce - 0.79, iou_score - 0.4838, fscore - 0.652, accuracy - 0.5779, recall - 0.7907, precision - 0.5548]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.21s/it, bce - 0.7802, iou_score - 0.3835, fscore - 0.5525, accuracy - 0.4244, recall - 0.7175, precision - 0.4501]
#
# Epoch: 4
# train: 100%|██████████| 4/4 [00:13<00:00,  3.25s/it, bce - 0.7585, iou_score - 0.5182, fscore - 0.6826, accuracy - 0.625, recall - 0.8061, precision - 0.592]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.36s/it, bce - 0.7745, iou_score - 0.3993, fscore - 0.5683, accuracy - 0.4575, recall - 0.7218, precision - 0.4696]
#
# Epoch: 5
# train: 100%|██████████| 4/4 [00:11<00:00,  2.99s/it, bce - 0.717, iou_score - 0.5626, fscore - 0.72, accuracy - 0.6769, recall - 0.8306, precision - 0.6356]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.01s/it, bce - 0.7609, iou_score - 0.4282, fscore - 0.596, accuracy - 0.5119, recall - 0.7287, precision - 0.5051]
#
# Epoch: 6
# train: 100%|██████████| 4/4 [00:11<00:00,  2.96s/it, bce - 0.7168, iou_score - 0.5752, fscore - 0.7301, accuracy - 0.6889, recall - 0.8399, precision - 0.6469]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.17s/it, bce - 0.7516, iou_score - 0.4733, fscore - 0.6379, accuracy - 0.5813, recall - 0.7493, precision - 0.5569]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 4/4 [00:13<00:00,  3.27s/it, bce - 0.6932, iou_score - 0.6047, fscore - 0.7536, accuracy - 0.7138, recall - 0.8754, precision - 0.662]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.28s/it, bce - 0.7135, iou_score - 0.5021, fscore - 0.6631, accuracy - 0.6172, recall - 0.7678, precision - 0.5854]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 4/4 [00:13<00:00,  3.25s/it, bce - 0.6863, iou_score - 0.6287, fscore - 0.7715, accuracy - 0.7447, recall - 0.8612, precision - 0.6989]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.20s/it, bce - 0.6279, iou_score - 0.5412, fscore - 0.697, accuracy - 0.6591, recall - 0.8016, precision - 0.6191]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 4/4 [00:12<00:00,  3.09s/it, bce - 0.6775, iou_score - 0.6643, fscore - 0.7981, accuracy - 0.7745, recall - 0.8924, precision - 0.722]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.83s/it, bce - 0.5998, iou_score - 0.5669, fscore - 0.72, accuracy - 0.6877, recall - 0.8215, precision - 0.6449]
# Model saved!
#
# Epoch: 10
# train: 100%|██████████| 4/4 [00:11<00:00,  2.85s/it, bce - 0.6357, iou_score - 0.7027, fscore - 0.8251, accuracy - 0.8083, recall - 0.9043, precision - 0.7589]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.76s/it, bce - 0.5909, iou_score - 0.5925, fscore - 0.7412, accuracy - 0.7176, recall - 0.8295, precision - 0.6763]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 4/4 [00:12<00:00,  3.18s/it, bce - 0.6456, iou_score - 0.7342, fscore - 0.8466, accuracy - 0.8289, recall - 0.9434, precision - 0.7681]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.33s/it, bce - 0.5733, iou_score - 0.6326, fscore - 0.7734, accuracy - 0.7548, recall - 0.8548, precision - 0.714]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 4/4 [00:12<00:00,  3.21s/it, bce - 0.6147, iou_score - 0.7734, fscore - 0.8722, accuracy - 0.8592, recall - 0.9607, precision - 0.7987]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.31s/it, bce - 0.5566, iou_score - 0.7217, fscore - 0.8379, accuracy - 0.8265, recall - 0.9059, precision - 0.784]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 4/4 [00:11<00:00,  2.82s/it, bce - 0.6243, iou_score - 0.7904, fscore - 0.8827, accuracy - 0.8721, recall - 0.9605, precision - 0.8169]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.11s/it, bce - 0.5329, iou_score - 0.8166, fscore - 0.8986, accuracy - 0.8955, recall - 0.9332, precision - 0.8681]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 4/4 [00:12<00:00,  3.12s/it, bce - 0.6065, iou_score - 0.7855, fscore - 0.8788, accuracy - 0.8672, recall - 0.9608, precision - 0.8097]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.30s/it, bce - 0.5167, iou_score - 0.8563, fscore - 0.9221, accuracy - 0.9202, recall - 0.9504, precision - 0.896]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 4/4 [00:12<00:00,  3.22s/it, bce - 0.5832, iou_score - 0.8327, fscore - 0.9087, accuracy - 0.902, recall - 0.9764, precision - 0.8502]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.17s/it, bce - 0.5105, iou_score - 0.8607, fscore - 0.9246, accuracy - 0.9225, recall - 0.9552, precision - 0.8962]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████| 4/4 [00:12<00:00,  3.00s/it, bce - 0.5685, iou_score - 0.8763, fscore - 0.9339, accuracy - 0.9304, recall - 0.9811, precision - 0.8912]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.00s/it, bce - 0.5031, iou_score - 0.8908, fscore - 0.9416, accuracy - 0.9403, recall - 0.9636, precision - 0.9205]
# Model saved!
#
# Epoch: 17
# train: 100%|██████████| 4/4 [00:11<00:00,  2.86s/it, bce - 0.5721, iou_score - 0.8909, fscore - 0.9422, accuracy - 0.9392, recall - 0.99, precision - 0.8989]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.72s/it, bce - 0.496, iou_score - 0.9262, fscore - 0.9614, accuracy - 0.9607, recall - 0.9789, precision - 0.9445]
# Model saved!
#
# Epoch: 18
# train: 100%|██████████| 4/4 [00:12<00:00,  3.18s/it, bce - 0.5537, iou_score - 0.9332, fscore - 0.9654, accuracy - 0.9643, recall - 0.994, precision - 0.9385]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.16s/it, bce - 0.5019, iou_score - 0.8767, fscore - 0.9317, accuracy - 0.9292, recall - 0.9555, precision - 0.9094]
#
# Epoch: 19
# train: 100%|██████████| 4/4 [00:12<00:00,  3.10s/it, bce - 0.5436, iou_score - 0.9514, fscore - 0.975, accuracy - 0.9744, recall - 0.995, precision - 0.956]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.17s/it, bce - 0.4922, iou_score - 0.8713, fscore - 0.928, accuracy - 0.9228, recall - 0.9663, precision - 0.8943]
#
# Epoch: 20
# train: 100%|██████████| 4/4 [00:12<00:00,  3.06s/it, bce - 0.5368, iou_score - 0.9129, fscore - 0.9533, accuracy - 0.9526, recall - 0.9679, precision - 0.9392]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.63s/it, bce - 0.4755, iou_score - 0.8938, fscore - 0.9416, accuracy - 0.9392, recall - 0.9642, precision - 0.9207]
#
# Epoch: 21
# train: 100%|██████████| 4/4 [00:10<00:00,  2.73s/it, bce - 0.5229, iou_score - 0.9697, fscore - 0.9846, accuracy - 0.9844, recall - 0.9953, precision - 0.9741]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.12s/it, bce - 0.4656, iou_score - 0.9466, fscore - 0.9722, accuracy - 0.9714, recall - 0.99, precision - 0.9554]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 4/4 [00:12<00:00,  3.20s/it, bce - 0.499, iou_score - 0.9774, fscore - 0.9886, accuracy - 0.9885, recall - 0.9961, precision - 0.9811]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.17s/it, bce - 0.4542, iou_score - 0.9667, fscore - 0.983, accuracy - 0.9828, recall - 0.9897, precision - 0.9764]
# Model saved!
#
# Epoch: 23
# train: 100%|██████████| 4/4 [00:12<00:00,  3.18s/it, bce - 0.4856, iou_score - 0.9688, fscore - 0.984, accuracy - 0.9839, recall - 0.9889, precision - 0.9791]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.29s/it, bce - 0.4452, iou_score - 0.9716, fscore - 0.9855, accuracy - 0.9853, recall - 0.9931, precision - 0.9781]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 4/4 [00:12<00:00,  3.01s/it, bce - 0.4794, iou_score - 0.9847, fscore - 0.9923, accuracy - 0.9922, recall - 0.9976, precision - 0.987]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.89s/it, bce - 0.4421, iou_score - 0.9688, fscore - 0.984, accuracy - 0.9838, recall - 0.9935, precision - 0.9749]
#
# Epoch: 25
# train: 100%|██████████| 4/4 [00:10<00:00,  2.63s/it, bce - 0.4913, iou_score - 0.9352, fscore - 0.9657, accuracy - 0.9655, recall - 0.9703, precision - 0.9612]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.93s/it, bce - 0.4286, iou_score - 0.9697, fscore - 0.9845, accuracy - 0.9843, recall - 0.994, precision - 0.9753]
#
# Epoch: 26
# train: 100%|██████████| 4/4 [00:12<00:00,  3.17s/it, bce - 0.4695, iou_score - 0.9528, fscore - 0.9754, accuracy - 0.9753, recall - 0.98, precision - 0.9709]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.30s/it, bce - 0.4128, iou_score - 0.9816, fscore - 0.9907, accuracy - 0.9907, recall - 0.9941, precision - 0.9873]
# Model saved!
#
# Epoch: 27
# train: 100%|██████████| 4/4 [00:12<00:00,  3.22s/it, bce - 0.4521, iou_score - 0.9891, fscore - 0.9945, accuracy - 0.9945, recall - 0.9986, precision - 0.9905]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.28s/it, bce - 0.4111, iou_score - 0.9713, fscore - 0.9853, accuracy - 0.9851, recall - 0.9941, precision - 0.9769]
#
# Epoch: 28
# train: 100%|██████████| 4/4 [00:11<00:00,  3.00s/it, bce - 0.4602, iou_score - 0.9529, fscore - 0.9749, accuracy - 0.9747, recall - 0.9787, precision - 0.971]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.71s/it, bce - 0.4056, iou_score - 0.9488, fscore - 0.9733, accuracy - 0.9722, recall - 0.9941, precision - 0.9541]
#
# Epoch: 29
# train: 100%|██████████| 4/4 [00:10<00:00,  2.70s/it, bce - 0.4346, iou_score - 0.9861, fscore - 0.993, accuracy - 0.9929, recall - 0.9964, precision - 0.9895]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.04s/it, bce - 0.4022, iou_score - 0.9356, fscore - 0.9659, accuracy - 0.964, recall - 0.9941, precision - 0.9406]
#
# Epoch: 30
# train: 100%|██████████| 4/4 [00:12<00:00,  3.03s/it, bce - 0.4138, iou_score - 0.9855, fscore - 0.9926, accuracy - 0.9926, recall - 0.9956, precision - 0.9897]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.27s/it, bce - 0.3988, iou_score - 0.913, fscore - 0.9529, accuracy - 0.9489, recall - 0.9941, precision - 0.9177]
#
# Epoch: 31
# train: 100%|██████████| 4/4 [00:12<00:00,  3.24s/it, bce - 0.4378, iou_score - 0.9612, fscore - 0.9794, accuracy - 0.9793, recall - 0.9827, precision - 0.9761]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.29s/it, bce - 0.3912, iou_score - 0.9329, fscore - 0.9644, accuracy - 0.9623, recall - 0.9941, precision - 0.9379]
#
# Epoch: 32
# train: 100%|██████████| 4/4 [00:12<00:00,  3.09s/it, bce - 0.4459, iou_score - 0.958, fscore - 0.9778, accuracy - 0.9777, recall - 0.9826, precision - 0.9731]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.49s/it, bce - 0.3841, iou_score - 0.9411, fscore - 0.9691, accuracy - 0.9678, recall - 0.994, precision - 0.9463]
#
# Epoch: 33
# train: 100%|██████████| 4/4 [00:11<00:00,  2.75s/it, bce - 0.4237, iou_score - 0.9587, fscore - 0.9785, accuracy - 0.9785, recall - 0.9808, precision - 0.9763]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.21s/it, bce - 0.3859, iou_score - 0.9485, fscore - 0.9732, accuracy - 0.9722, recall - 0.994, precision - 0.9539]
#
# Epoch: 34
# train: 100%|██████████| 4/4 [00:11<00:00,  2.91s/it, bce - 0.3989, iou_score - 0.9937, fscore - 0.9968, accuracy - 0.9968, recall - 0.9989, precision - 0.9948]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.53s/it, bce - 0.3749, iou_score - 0.9838, fscore - 0.9918, accuracy - 0.9918, recall - 0.9941, precision - 0.9896]
# Model saved!
#
# Epoch: 35
# train: 100%|██████████| 4/4 [00:12<00:00,  3.16s/it, bce - 0.401, iou_score - 0.9778, fscore - 0.9885, accuracy - 0.9885, recall - 0.9905, precision - 0.9866]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.16s/it, bce - 0.3651, iou_score - 0.9852, fscore - 0.9925, accuracy - 0.9925, recall - 0.9942, precision - 0.9908]
# Model saved!
#
# Epoch: 36
# train: 100%|██████████| 4/4 [00:12<00:00,  3.16s/it, bce - 0.4215, iou_score - 0.9449, fscore - 0.9708, accuracy - 0.9707, recall - 0.9735, precision - 0.9681]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.76s/it, bce - 0.3621, iou_score - 0.9859, fscore - 0.9929, accuracy - 0.9929, recall - 0.9942, precision - 0.9916]
# Model saved!
#
# Epoch: 37
# train: 100%|██████████| 4/4 [00:10<00:00,  2.74s/it, bce - 0.4016, iou_score - 0.9655, fscore - 0.9821, accuracy - 0.9821, recall - 0.9844, precision - 0.9799]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.11s/it, bce - 0.3524, iou_score - 0.9868, fscore - 0.9934, accuracy - 0.9933, recall - 0.9942, precision - 0.9925]
# Model saved!
#
# Epoch: 38
# train: 100%|██████████| 4/4 [00:12<00:00,  3.22s/it, bce - 0.3848, iou_score - 0.9776, fscore - 0.9886, accuracy - 0.9885, recall - 0.9905, precision - 0.9866]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.18s/it, bce - 0.3413, iou_score - 0.9867, fscore - 0.9933, accuracy - 0.9933, recall - 0.9942, precision - 0.9924]
#
# Epoch: 39
# train: 100%|██████████| 4/4 [00:12<00:00,  3.12s/it, bce - 0.3767, iou_score - 0.9656, fscore - 0.9822, accuracy - 0.9822, recall - 0.9836, precision - 0.9808]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.15s/it, bce - 0.3393, iou_score - 0.9879, fscore - 0.9939, accuracy - 0.9939, recall - 0.9942, precision - 0.9936]
# Model saved!
#
# Epoch: 40
# train: 100%|██████████| 4/4 [00:12<00:00,  3.09s/it, bce - 0.3648, iou_score - 0.9934, fscore - 0.9967, accuracy - 0.9967, recall - 0.9983, precision - 0.995]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.75s/it, bce - 0.3365, iou_score - 0.988, fscore - 0.994, accuracy - 0.994, recall - 0.9942, precision - 0.9937]
# Model saved!
#
# Epoch: 41
# train: 100%|██████████| 4/4 [00:11<00:00,  2.90s/it, bce - 0.3621, iou_score - 0.9785, fscore - 0.9889, accuracy - 0.9888, recall - 0.9902, precision - 0.9875]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.92s/it, bce - 0.3348, iou_score - 0.9877, fscore - 0.9938, accuracy - 0.9938, recall - 0.9943, precision - 0.9934]
#
# Epoch: 42
# train: 100%|██████████| 4/4 [00:12<00:00,  3.14s/it, bce - 0.3805, iou_score - 0.9253, fscore - 0.9605, accuracy - 0.9605, recall - 0.9616, precision - 0.9594]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.17s/it, bce - 0.3264, iou_score - 0.9879, fscore - 0.9939, accuracy - 0.9939, recall - 0.9943, precision - 0.9936]
#
# Epoch: 43
# train: 100%|██████████| 4/4 [00:12<00:00,  3.12s/it, bce - 0.3579, iou_score - 0.96, fscore - 0.9791, accuracy - 0.979, recall - 0.9804, precision - 0.9777]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.19s/it, bce - 0.319, iou_score - 0.9879, fscore - 0.9939, accuracy - 0.9939, recall - 0.9943, precision - 0.9936]
#
# Epoch: 44
# train: 100%|██████████| 4/4 [00:12<00:00,  3.04s/it, bce - 0.3366, iou_score - 0.9897, fscore - 0.9948, accuracy - 0.9948, recall - 0.9958, precision - 0.9938]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.64s/it, bce - 0.3191, iou_score - 0.9881, fscore - 0.994, accuracy - 0.994, recall - 0.9943, precision - 0.9938]
# Model saved!
#
# Epoch: 45
# train: 100%|██████████| 4/4 [00:10<00:00,  2.71s/it, bce - 0.3309, iou_score - 0.9972, fscore - 0.9986, accuracy - 0.9986, recall - 0.9996, precision - 0.9976]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.04s/it, bce - 0.3251, iou_score - 0.9876, fscore - 0.9938, accuracy - 0.9937, recall - 0.9943, precision - 0.9933]
#
# Epoch: 46
# train: 100%|██████████| 4/4 [00:12<00:00,  3.18s/it, bce - 0.3303, iou_score - 0.9974, fscore - 0.9987, accuracy - 0.9987, recall - 0.9997, precision - 0.9977]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.30s/it, bce - 0.3271, iou_score - 0.988, fscore - 0.994, accuracy - 0.994, recall - 0.9943, precision - 0.9937]
#
# Epoch: 47
# train: 100%|██████████| 4/4 [00:12<00:00,  3.11s/it, bce - 0.3205, iou_score - 0.991, fscore - 0.9955, accuracy - 0.9955, recall - 0.9962, precision - 0.9947]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.20s/it, bce - 0.3212, iou_score - 0.988, fscore - 0.994, accuracy - 0.994, recall - 0.9942, precision - 0.9937]
#
# Epoch: 48
# train: 100%|██████████| 4/4 [00:12<00:00,  3.09s/it, bce - 0.3451, iou_score - 0.9517, fscore - 0.9747, accuracy - 0.9746, recall - 0.9755, precision - 0.9738]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.59s/it, bce - 0.3174, iou_score - 0.988, fscore - 0.9939, accuracy - 0.9939, recall - 0.9943, precision - 0.9936]
#
# Epoch: 49
# train: 100%|██████████| 4/4 [00:10<00:00,  2.72s/it, bce - 0.3257, iou_score - 0.983, fscore - 0.9913, accuracy - 0.9913, recall - 0.9922, precision - 0.9903]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.10s/it, bce - 0.3124, iou_score - 0.9881, fscore - 0.994, accuracy - 0.994, recall - 0.9943, precision - 0.9938]
# Model saved!
#
# Epoch: 50
# train: 100%|██████████| 4/4 [00:12<00:00,  3.08s/it, bce - 0.3379, iou_score - 0.944, fscore - 0.9706, accuracy - 0.9706, recall - 0.9713, precision - 0.9699]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.40s/it, bce - 0.3083, iou_score - 0.9882, fscore - 0.9941, accuracy - 0.9941, recall - 0.9943, precision - 0.9939]
# Model saved!
#
# Epoch: 51
# train: 100%|██████████| 4/4 [00:12<00:00,  3.18s/it, bce - 0.3079, iou_score - 0.998, fscore - 0.999, accuracy - 0.999, recall - 0.9998, precision - 0.9983]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.39s/it, bce - 0.2982, iou_score - 0.9879, fscore - 0.9939, accuracy - 0.9939, recall - 0.9943, precision - 0.9936]
#
# Epoch: 52
# train: 100%|██████████| 4/4 [00:11<00:00,  2.96s/it, bce - 0.3259, iou_score - 0.972, fscore - 0.9853, accuracy - 0.9853, recall - 0.986, precision - 0.9845]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.89s/it, bce - 0.2884, iou_score - 0.9884, fscore - 0.9942, accuracy - 0.9942, recall - 0.9943, precision - 0.9941]
# Model saved!
#
# Epoch: 53
# train: 100%|██████████| 4/4 [00:11<00:00,  2.92s/it, bce - 0.3191, iou_score - 0.983, fscore - 0.9913, accuracy - 0.9912, recall - 0.9922, precision - 0.9903]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.77s/it, bce - 0.2773, iou_score - 0.9886, fscore - 0.9942, accuracy - 0.9942, recall - 0.9943, precision - 0.9942]
# Model saved!
#
# Epoch: 54
# train: 100%|██████████| 4/4 [00:12<00:00,  3.18s/it, bce - 0.298, iou_score - 0.9837, fscore - 0.9916, accuracy - 0.9916, recall - 0.9922, precision - 0.9911]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.20s/it, bce - 0.2724, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]

# valid: 100%|██████████| 2/2 [00:07<00:00,  3.60s/it, bce - 0.1334, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 121
# train: 100%|██████████| 4/4 [00:12<00:00,  3.11s/it, bce - 0.1431, iou_score - 0.9812, fscore - 0.9902, accuracy - 0.9902, recall - 0.9904, precision - 0.99]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.41s/it, bce - 0.1345, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 122
# train: 100%|██████████| 4/4 [00:14<00:00,  3.58s/it, bce - 0.1327, iou_score - 0.9994, fscore - 0.9997, accuracy - 0.9997, recall - 0.9999, precision - 0.9995]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.55s/it, bce - 0.1373, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 123
# train: 100%|██████████| 4/4 [00:11<00:00,  2.78s/it, bce - 0.1485, iou_score - 0.9727, fscore - 0.9856, accuracy - 0.9856, recall - 0.9858, precision - 0.9854]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.07s/it, bce - 0.1303, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 124
# train: 100%|██████████| 4/4 [00:11<00:00,  2.94s/it, bce - 0.1663, iou_score - 0.96, fscore - 0.9792, accuracy - 0.9792, recall - 0.9794, precision - 0.979]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.54s/it, bce - 0.1254, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 125
# train: 100%|██████████| 4/4 [00:12<00:00,  3.14s/it, bce - 0.1305, iou_score - 0.9995, fscore - 0.9998, accuracy - 0.9998, recall - 1.0, precision - 0.9996]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.19s/it, bce - 0.1238, iou_score - 0.9886, fscore - 0.9942, accuracy - 0.9942, recall - 0.9943, precision - 0.9942]
#
# Epoch: 126
# train: 100%|██████████| 4/4 [00:12<00:00,  3.14s/it, bce - 0.1437, iou_score - 0.9886, fscore - 0.9942, accuracy - 0.9942, recall - 0.9945, precision - 0.9939]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.55s/it, bce - 0.1275, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9942]
#
# Epoch: 127
# train: 100%|██████████| 4/4 [00:11<00:00,  2.87s/it, bce - 0.1335, iou_score - 0.9993, fscore - 0.9996, accuracy - 0.9996, recall - 1.0, precision - 0.9993]
# valid: 100%|██████████| 2/2 [00:07<00:00,  4.00s/it, bce - 0.1297, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9942]
#
# Epoch: 128
# train: 100%|██████████| 4/4 [00:12<00:00,  3.06s/it, bce - 0.1269, iou_score - 0.9963, fscore - 0.9982, accuracy - 0.9982, recall - 0.9984, precision - 0.9979]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.74s/it, bce - 0.1294, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9942]
#
# Epoch: 129
# train: 100%|██████████| 4/4 [00:12<00:00,  3.10s/it, bce - 0.1339, iou_score - 0.9884, fscore - 0.9941, accuracy - 0.9941, recall - 0.9944, precision - 0.9938]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.20s/it, bce - 0.1278, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 130
# train: 100%|██████████| 4/4 [00:12<00:00,  3.10s/it, bce - 0.1961, iou_score - 0.9404, fscore - 0.9681, accuracy - 0.9681, recall - 0.9684, precision - 0.9678]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.16s/it, bce - 0.1237, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 131
# train: 100%|██████████| 4/4 [00:11<00:00,  2.89s/it, bce - 0.1205, iou_score - 0.9996, fscore - 0.9998, accuracy - 0.9998, recall - 1.0, precision - 0.9996]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.14s/it, bce - 0.1256, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 132
# train: 100%|██████████| 4/4 [00:11<00:00,  2.78s/it, bce - 0.1247, iou_score - 0.9935, fscore - 0.9967, accuracy - 0.9967, recall - 0.9969, precision - 0.9965]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.78s/it, bce - 0.1199, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 133
# train: 100%|██████████| 4/4 [00:12<00:00,  3.09s/it, bce - 0.1218, iou_score - 0.9995, fscore - 0.9997, accuracy - 0.9997, recall - 1.0, precision - 0.9995]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.18s/it, bce - 0.1208, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 134
# train: 100%|██████████| 4/4 [00:12<00:00,  3.12s/it, bce - 0.1403, iou_score - 0.9777, fscore - 0.9886, accuracy - 0.9886, recall - 0.9889, precision - 0.9883]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.20s/it, bce - 0.1182, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 135
# train: 100%|██████████| 4/4 [00:12<00:00,  3.13s/it, bce - 0.1223, iou_score - 0.9966, fscore - 0.9983, accuracy - 0.9983, recall - 0.9985, precision - 0.9981]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.63s/it, bce - 0.1132, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 136
# train: 100%|██████████| 4/4 [00:10<00:00,  2.66s/it, bce - 0.131, iou_score - 0.9855, fscore - 0.9926, accuracy - 0.9926, recall - 0.9928, precision - 0.9924]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.23s/it, bce - 0.1126, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 137
# train: 100%|██████████| 4/4 [00:12<00:00,  3.07s/it, bce - 0.1492, iou_score - 0.9732, fscore - 0.9859, accuracy - 0.9859, recall - 0.9861, precision - 0.9856]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.28s/it, bce - 0.1125, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 138
# train: 100%|██████████| 4/4 [00:12<00:00,  3.13s/it, bce - 0.1792, iou_score - 0.9401, fscore - 0.968, accuracy - 0.968, recall - 0.9682, precision - 0.9678]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.19s/it, bce - 0.1074, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 139
# train: 100%|██████████| 4/4 [00:12<00:00,  3.13s/it, bce - 0.1181, iou_score - 0.9879, fscore - 0.9938, accuracy - 0.9938, recall - 0.994, precision - 0.9936]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.33s/it, bce - 0.1114, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 140
# train: 100%|██████████| 4/4 [00:11<00:00,  2.85s/it, bce - 0.1154, iou_score - 0.9943, fscore - 0.9971, accuracy - 0.9971, recall - 0.9973, precision - 0.9969]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.01s/it, bce - 0.1155, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 141
# train: 100%|██████████| 4/4 [00:12<00:00,  3.02s/it, bce - 0.1585, iou_score - 0.9698, fscore - 0.9839, accuracy - 0.9839, recall - 0.9842, precision - 0.9837]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.07s/it, bce - 0.1154, iou_score - 0.9886, fscore - 0.9942, accuracy - 0.9942, recall - 0.9943, precision - 0.9942]
#
# Epoch: 142
# train: 100%|██████████| 4/4 [00:12<00:00,  3.11s/it, bce - 0.1327, iou_score - 0.9759, fscore - 0.9877, accuracy - 0.9877, recall - 0.9879, precision - 0.9874]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.20s/it, bce - 0.1116, iou_score - 0.9886, fscore - 0.9942, accuracy - 0.9942, recall - 0.9943, precision - 0.9942]
#
# Epoch: 143
# train: 100%|██████████| 4/4 [00:12<00:00,  3.12s/it, bce - 0.1422, iou_score - 0.9788, fscore - 0.9889, accuracy - 0.9889, recall - 0.9893, precision - 0.9886]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.27s/it, bce - 0.1056, iou_score - 0.9886, fscore - 0.9942, accuracy - 0.9942, recall - 0.9943, precision - 0.9942]
#
# Epoch: 144
# ...
#
# Epoch: 252
# train: 100%|██████████| 4/4 [00:12<00:00,  3.02s/it, bce - 0.05009, iou_score - 0.9998, fscore - 0.9999, accuracy - 0.9999, recall - 1.0, precision - 0.9998]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.31s/it, bce - 0.04608, iou_score - 0.9912, fscore - 0.9956, accuracy - 0.9956, recall - 0.9955, precision - 0.9956]
#
# Epoch: 253
# train: 100%|██████████| 4/4 [00:12<00:00,  3.08s/it, bce - 0.0916, iou_score - 0.9731, fscore - 0.9858, accuracy - 0.9858, recall - 0.9859, precision - 0.9857]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.18s/it, bce - 0.04523, iou_score - 0.9922, fscore - 0.9961, accuracy - 0.9961, recall - 0.996, precision - 0.9961]
#
# Epoch: 254
# train: 100%|██████████| 4/4 [00:12<00:00,  3.10s/it, bce - 0.1193, iou_score - 0.9584, fscore - 0.9782, accuracy - 0.9782, recall - 0.9783, precision - 0.9781]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.26s/it, bce - 0.04358, iou_score - 0.9924, fscore - 0.9962, accuracy - 0.9962, recall - 0.9961, precision - 0.9963]
#
# Epoch: 255
# train: 100%|██████████| 4/4 [00:11<00:00,  2.85s/it, bce - 0.05278, iou_score - 0.9998, fscore - 0.9999, accuracy - 0.9999, recall - 1.0, precision - 0.9998]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.90s/it, bce - 0.04284, iou_score - 0.9919, fscore - 0.9959, accuracy - 0.9959, recall - 0.9958, precision - 0.996]
#
# Epoch: 256
# train: 100%|██████████| 4/4 [00:13<00:00,  3.41s/it, bce - 0.05477, iou_score - 0.9987, fscore - 0.9993, accuracy - 0.9993, recall - 0.9994, precision - 0.9993]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.53s/it, bce - 0.04528, iou_score - 0.9894, fscore - 0.9947, accuracy - 0.9947, recall - 0.9946, precision - 0.9947]
#
# Epoch: 257
# train: 100%|██████████| 4/4 [00:12<00:00,  3.08s/it, bce - 0.06021, iou_score - 0.9883, fscore - 0.994, accuracy - 0.994, recall - 0.9941, precision - 0.9939]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.17s/it, bce - 0.04533, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 258
# train: 100%|██████████| 4/4 [00:12<00:00,  3.07s/it, bce - 0.114, iou_score - 0.959, fscore - 0.9786, accuracy - 0.9786, recall - 0.9787, precision - 0.9785]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.24s/it, bce - 0.04389, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 259
# train: 100%|██████████| 4/4 [00:11<00:00,  2.88s/it, bce - 0.04864, iou_score - 0.9998, fscore - 0.9999, accuracy - 0.9999, recall - 1.0, precision - 0.9998]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.87s/it, bce - 0.04387, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 260
# train: 100%|██████████| 4/4 [00:11<00:00,  2.77s/it, bce - 0.06207, iou_score - 0.9931, fscore - 0.9965, accuracy - 0.9965, recall - 0.9967, precision - 0.9964]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.78s/it, bce - 0.04562, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 261
# train: 100%|██████████| 4/4 [00:12<00:00,  3.09s/it, bce - 0.0642, iou_score - 0.9839, fscore - 0.9918, accuracy - 0.9918, recall - 0.9919, precision - 0.9916]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.32s/it, bce - 0.04356, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 262
# train: 100%|██████████| 4/4 [00:12<00:00,  3.09s/it, bce - 0.04991, iou_score - 0.9997, fscore - 0.9999, accuracy - 0.9999, recall - 1.0, precision - 0.9997]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.25s/it, bce - 0.04404, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 263
# train: 100%|██████████| 4/4 [00:11<00:00,  2.99s/it, bce - 0.1313, iou_score - 0.942, fscore - 0.9691, accuracy - 0.9691, recall - 0.9692, precision - 0.969]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.64s/it, bce - 0.04073, iou_score - 0.9891, fscore - 0.9945, accuracy - 0.9945, recall - 0.9944, precision - 0.9947]
#
# Epoch: 264
# train: 100%|██████████| 4/4 [00:10<00:00,  2.66s/it, bce - 0.05575, iou_score - 0.9913, fscore - 0.9956, accuracy - 0.9956, recall - 0.9955, precision - 0.9956]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.06s/it, bce - 0.0415, iou_score - 0.9892, fscore - 0.9946, accuracy - 0.9946, recall - 0.9944, precision - 0.9948]
#
# Epoch: 265
# train: 100%|██████████| 4/4 [00:11<00:00,  2.94s/it, bce - 0.05476, iou_score - 0.9963, fscore - 0.9982, accuracy - 0.9982, recall - 0.9983, precision - 0.9981]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.44s/it, bce - 0.0438, iou_score - 0.9897, fscore - 0.9948, accuracy - 0.9948, recall - 0.9946, precision - 0.9951]
#
# Epoch: 266
# train: 100%|██████████| 4/4 [00:12<00:00,  3.10s/it, bce - 0.06178, iou_score - 0.9781, fscore - 0.9885, accuracy - 0.9885, recall - 0.9886, precision - 0.9884]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.33s/it, bce - 0.04389, iou_score - 0.991, fscore - 0.9955, accuracy - 0.9955, recall - 0.9952, precision - 0.9958]
#
# Epoch: 267
# train: 100%|██████████| 4/4 [00:12<00:00,  3.08s/it, bce - 0.0485, iou_score - 0.9998, fscore - 0.9999, accuracy - 0.9999, recall - 1.0, precision - 0.9998]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.30s/it, bce - 0.04459, iou_score - 0.9925, fscore - 0.9962, accuracy - 0.9962, recall - 0.996, precision - 0.9964]
#
# Epoch: 268
# train: 100%|██████████| 4/4 [00:11<00:00,  2.82s/it, bce - 0.05754, iou_score - 0.993, fscore - 0.9964, accuracy - 0.9964, recall - 0.9964, precision - 0.9965]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.81s/it, bce - 0.04208, iou_score - 0.9918, fscore - 0.9959, accuracy - 0.9959, recall - 0.9957, precision - 0.9961]
#
# Epoch: 269
# train: 100%|██████████| 4/4 [00:10<00:00,  2.68s/it, bce - 0.05292, iou_score - 0.995, fscore - 0.9975, accuracy - 0.9975, recall - 0.9976, precision - 0.9974]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.88s/it, bce - 0.04219, iou_score - 0.9901, fscore - 0.995, accuracy - 0.995, recall - 0.9949, precision - 0.9952]
#
# Epoch: 270
# train: 100%|██████████| 4/4 [00:13<00:00,  3.26s/it, bce - 0.05185, iou_score - 0.9957, fscore - 0.9978, accuracy - 0.9978, recall - 0.9979, precision - 0.9977]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.16s/it, bce - 0.04352, iou_score - 0.989, fscore - 0.9945, accuracy - 0.9945, recall - 0.9944, precision - 0.9946]
#
# Epoch: 271
# train: 100%|██████████| 4/4 [00:12<00:00,  3.09s/it, bce - 0.04527, iou_score - 0.9998, fscore - 0.9999, accuracy - 0.9999, recall - 1.0, precision - 0.9998]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.37s/it, bce - 0.04399, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 272
# train: 100%|██████████| 4/4 [00:11<00:00,  2.96s/it, bce - 0.1193, iou_score - 0.9515, fscore - 0.9745, accuracy - 0.9745, recall - 0.9746, precision - 0.9743]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.67s/it, bce - 0.04047, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 273
# train: 100%|██████████| 4/4 [00:10<00:00,  2.67s/it, bce - 0.0624, iou_score - 0.9768, fscore - 0.9878, accuracy - 0.9878, recall - 0.988, precision - 0.9877]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.10s/it, bce - 0.03863, iou_score - 0.9894, fscore - 0.9947, accuracy - 0.9947, recall - 0.9944, precision - 0.9949]
#
# Epoch: 274
# train: 100%|██████████| 4/4 [00:14<00:00,  3.54s/it, bce - 0.05628, iou_score - 0.992, fscore - 0.9959, accuracy - 0.9959, recall - 0.996, precision - 0.9958]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.20s/it, bce - 0.03921, iou_score - 0.9918, fscore - 0.9959, accuracy - 0.9959, recall - 0.9955, precision - 0.9963]
#
# Epoch: 275
# train: 100%|██████████| 4/4 [00:12<00:00,  3.08s/it, bce - 0.04743, iou_score - 0.9996, fscore - 0.9998, accuracy - 0.9998, recall - 0.9998, precision - 0.9998]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.20s/it, bce - 0.04012, iou_score - 0.9919, fscore - 0.9959, accuracy - 0.9959, recall - 0.9955, precision - 0.9963]
#
# Epoch: 276
# train: 100%|██████████| 4/4 [00:11<00:00,  2.95s/it, bce - 0.1121, iou_score - 0.9605, fscore - 0.9791, accuracy - 0.9791, recall - 0.979, precision - 0.9792]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.99s/it, bce - 0.04123, iou_score - 0.9917, fscore - 0.9958, accuracy - 0.9958, recall - 0.9954, precision - 0.9963]
#
# Epoch: 277
# train: 100%|██████████| 4/4 [00:12<00:00,  3.10s/it, bce - 0.09925, iou_score - 0.9671, fscore - 0.9827, accuracy - 0.9828, recall - 0.9825, precision - 0.983]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.64s/it, bce - 0.04144, iou_score - 0.9897, fscore - 0.9948, accuracy - 0.9948, recall - 0.9944, precision - 0.9952]
#
# Epoch: 278
# train: 100%|██████████| 4/4 [00:12<00:00,  3.09s/it, bce - 0.04363, iou_score - 0.9998, fscore - 0.9999, accuracy - 0.9999, recall - 1.0, precision - 0.9998]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.17s/it, bce - 0.04333, iou_score - 0.9886, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9943]
#
# Epoch: 279
# train: 100%|██████████| 4/4 [00:12<00:00,  3.15s/it, bce - 0.09474, iou_score - 0.9506, fscore - 0.9733, accuracy - 0.9733, recall - 0.9733, precision - 0.9732]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.18s/it, bce - 0.04114, iou_score - 0.9888, fscore - 0.9943, accuracy - 0.9943, recall - 0.9943, precision - 0.9944]
#
# Epoch: 280
# train: 100%|██████████| 4/4 [00:12<00:00,  3.02s/it, bce - 0.1138, iou_score - 0.9645, fscore - 0.9809, accuracy - 0.9809, recall - 0.9809, precision - 0.9808]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.64s/it, bce - 0.04141, iou_score - 0.9897, fscore - 0.9948, accuracy - 0.9948, recall - 0.9943, precision - 0.9953]
#
# Epoch: 281
# train: 100%|██████████| 4/4 [00:11<00:00,  2.98s/it, bce - 0.04924, iou_score - 0.9892, fscore - 0.9945, accuracy - 0.9945, recall - 0.9946, precision - 0.9944]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.98s/it, bce - 0.04495, iou_score - 0.9901, fscore - 0.995, accuracy - 0.995, recall - 0.9946, precision - 0.9954]
#
# Epoch: 282
# train: 100%|██████████| 4/4 [00:10<00:00,  2.66s/it, bce - 0.07497, iou_score - 0.975, fscore - 0.9871, accuracy - 0.9872, recall - 0.9872, precision - 0.9871]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.95s/it, bce - 0.04765, iou_score - 0.9916, fscore - 0.9958, accuracy - 0.9958, recall - 0.9955, precision - 0.9961]
#
# Epoch: 283
# train: 100%|██████████| 4/4 [00:12<00:00,  3.05s/it, bce - 0.09, iou_score - 0.9648, fscore - 0.9818, accuracy - 0.9818, recall - 0.9815, precision - 0.982]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.27s/it, bce - 0.04763, iou_score - 0.9919, fscore - 0.996, accuracy - 0.996, recall - 0.9957, precision - 0.9962]
#
# Epoch: 284
# train: 100%|██████████| 4/4 [00:12<00:00,  3.08s/it, bce - 0.04436, iou_score - 0.9998, fscore - 0.9999, accuracy - 0.9999, recall - 1.0, precision - 0.9998]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.16s/it, bce - 0.0464, iou_score - 0.992, fscore - 0.996, accuracy - 0.996, recall - 0.9957, precision - 0.9962]
#
# Epoch: 285
# train: 100%|██████████| 4/4 [00:12<00:00,  3.10s/it, bce - 0.09582, iou_score - 0.9696, fscore - 0.9838, accuracy - 0.9838, recall - 0.9839, precision - 0.9837]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.33s/it, bce - 0.04544, iou_score - 0.9911, fscore - 0.9955, accuracy - 0.9955, recall - 0.9953, precision - 0.9957]
#
# Epoch: 286
# train: 100%|██████████| 4/4 [00:10<00:00,  2.74s/it, bce - 0.04277, iou_score - 0.9998, fscore - 0.9999, accuracy - 0.9999, recall - 1.0, precision - 0.9998]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.19s/it, bce - 0.04516, iou_score - 0.9904, fscore - 0.9952, accuracy - 0.9952, recall - 0.995, precision - 0.9953]
#
# Epoch: 287
# train: 100%|██████████| 4/4 [00:11<00:00,  2.87s/it, bce - 0.06867, iou_score - 0.9735, fscore - 0.9863, accuracy - 0.9863, recall - 0.9864, precision - 0.9862]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.55s/it, bce - 0.04252, iou_score - 0.991, fscore - 0.9955, accuracy - 0.9955, recall - 0.9952, precision - 0.9957]
#
# Epoch: 288
# train: 100%|██████████| 4/4 [00:12<00:00,  3.09s/it, bce - 0.04301, iou_score - 0.9998, fscore - 0.9999, accuracy - 0.9999, recall - 1.0, precision - 0.9998]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.16s/it, bce - 0.04235, iou_score - 0.993, fscore - 0.9965, accuracy - 0.9965, recall - 0.9963, precision - 0.9967]
#
# Epoch: 289
# train: 100%|██████████| 4/4 [00:12<00:00,  3.07s/it, bce - 0.04148, iou_score - 0.9998, fscore - 0.9999, accuracy - 0.9999, recall - 1.0, precision - 0.9998]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.18s/it, bce - 0.04223, iou_score - 0.9935, fscore - 0.9967, accuracy - 0.9967, recall - 0.9966, precision - 0.9969]
#
# Epoch: 290
# train: 100%|██████████| 4/4 [00:11<00:00,  2.99s/it, bce - 0.04232, iou_score - 0.9998, fscore - 0.9999, accuracy - 0.9999, recall - 1.0, precision - 0.9998]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.76s/it, bce - 0.04111, iou_score - 0.9936, fscore - 0.9968, accuracy - 0.9968, recall - 0.9967, precision - 0.9969]
#
# Epoch: 291
# train: 100%|██████████| 4/4 [00:10<00:00,  2.61s/it, bce - 0.06984, iou_score - 0.9714, fscore - 0.9851, accuracy - 0.9851, recall - 0.9848, precision - 0.9854]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.14s/it, bce - 0.03953, iou_score - 0.9938, fscore - 0.9969, accuracy - 0.9969, recall - 0.9968, precision - 0.997]
#
# Epoch: 292
# train: 100%|██████████| 4/4 [00:12<00:00,  3.04s/it, bce - 0.04077, iou_score - 0.9998, fscore - 0.9999, accuracy - 0.9999, recall - 1.0, precision - 0.9998]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.21s/it, bce - 0.03903, iou_score - 0.9935, fscore - 0.9968, accuracy - 0.9968, recall - 0.9967, precision - 0.9968]
#
# Epoch: 293
# train: 100%|██████████| 4/4 [00:12<00:00,  3.12s/it, bce - 0.04899, iou_score - 0.9829, fscore - 0.9912, accuracy - 0.9912, recall - 0.9912, precision - 0.9911]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.97s/it, bce - 0.03859, iou_score - 0.9942, fscore - 0.9971, accuracy - 0.9971, recall - 0.9971, precision - 0.9971]
# Model saved!
#
# Epoch: 294
# train: 100%|██████████| 4/4 [00:11<00:00,  2.91s/it, bce - 0.0884, iou_score - 0.976, fscore - 0.9874, accuracy - 0.9874, recall - 0.9875, precision - 0.9873]
# valid: 100%|██████████| 2/2 [00:08<00:00,  4.13s/it, bce - 0.03942, iou_score - 0.9942, fscore - 0.9971, accuracy - 0.9971, recall - 0.9971, precision - 0.9971]
# Model saved!
#
# Epoch: 295
# train: 100%|██████████| 4/4 [00:11<00:00,  2.80s/it, bce - 0.07624, iou_score - 0.9748, fscore - 0.9867, accuracy - 0.9868, recall - 0.9866, precision - 0.9869]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.70s/it, bce - 0.03889, iou_score - 0.9942, fscore - 0.9971, accuracy - 0.9971, recall - 0.997, precision - 0.9971]
#
# Epoch: 296
# train: 100%|██████████| 4/4 [00:12<00:00,  3.12s/it, bce - 0.0414, iou_score - 0.999, fscore - 0.9995, accuracy - 0.9995, recall - 0.9996, precision - 0.9994]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.44s/it, bce - 0.03965, iou_score - 0.9937, fscore - 0.9968, accuracy - 0.9968, recall - 0.9968, precision - 0.9969]
#
# Epoch: 297
# train: 100%|██████████| 4/4 [00:12<00:00,  3.17s/it, bce - 0.09071, iou_score - 0.9663, fscore - 0.9824, accuracy - 0.9824, recall - 0.9825, precision - 0.9824]
# valid: 100%|██████████| 2/2 [00:06<00:00,  3.30s/it, bce - 0.03962, iou_score - 0.9935, fscore - 0.9968, accuracy - 0.9968, recall - 0.9967, precision - 0.9968]
#
# Epoch: 298
# train: 100%|██████████| 4/4 [00:11<00:00,  2.83s/it, bce - 0.0466, iou_score - 0.9949, fscore - 0.9974, accuracy - 0.9974, recall - 0.9975, precision - 0.9973]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.90s/it, bce - 0.0402, iou_score - 0.9927, fscore - 0.9963, accuracy - 0.9963, recall - 0.9963, precision - 0.9964]
#
# Epoch: 299
# train: 100%|██████████| 4/4 [00:10<00:00,  2.68s/it, bce - 0.0657, iou_score - 0.9628, fscore - 0.9807, accuracy - 0.9807, recall - 0.9803, precision - 0.9811]
# valid: 100%|██████████| 2/2 [00:07<00:00,  3.82s/it, bce - 0.03923, iou_score - 0.9938, fscore - 0.9969, accuracy - 0.9969, recall - 0.9969, precision - 0.9969]
